# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
world = pd.read_csv("archivos_pair/world_data_full.csv", index_col=0)

# %%
world.head(3)
# Out:
#        country density abbreviation  agricultural_land  land_area  \
# 0  Afghanistan      60           AF               58.1    652,230
# 1      Albania     105           AL               43.1     28,748
# 2      Algeria      18           DZ               17.4  2,381,741
#
#   armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0           323,000       32.49          93.0              Kabul
# 1             9,000       11.78         355.0             Tirana
# 2           317,000       24.28         213.0            Algiers
#
#   co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# 0         8,672   149.9         2.3           AFN            4.47
# 1         4,536  119.05         1.4           ALL            1.62
# 2       150,006  151.36         2.0           DZD            3.02
#
#    forested_area  gasoline_price               gdp  \
# 0            2.1            0.70   19,101,353,833
# 1           28.1            1.36   15,278,077,447
# 2            0.8            0.28  169,988,236,398
#
#    gross_primary_education_enrollment  gross_tertiary_education_enrollment  \
# 0                               104.0                                  9.7
# 1                               107.0                                 55.0
# 2                               109.9                                 51.4
#
#    infant_mortality largest_city  life_expectancy  maternal_mortality_ratio  \
# 0              47.9        Kabul             64.5                     638.0
# 1               7.8       Tirana             78.5                      15.0
# 2              20.1      Algiers             76.7                     112.0
#
#    minimum_wage official_language  out_of_pocket_health_expenditure  \
# 0          0.43            Pashto                              78.4
# 1          1.12          Albanian                              56.9
# 2          0.95            Arabic                              28.1
#
#    physicians_per_thousand  population  population_labor_force_participation  \
# 0                     0.28  38,041,754                                  48.9
# 1                     1.20   2,854,191                                  55.7
# 2                     1.72  43,053,054                                  41.2
#
#    tax_revenue  total_tax_rate  unemployment_rate urban_population  \
# 0          9.3            71.4              11.12        9,797,273
# 1         18.6            36.6              12.33        1,747,593
# 2         37.2            66.1              11.70       31,510,100
#
#      latitude   longitude
# 0   33.93911    67.709953
# 1  41.153332    20.168331
# 2  28.033886     1.659626

# %% [markdown]
# 1. Las columnas land_area, armed_forces_size, co2-emissions, gdp, population, urban_population, latitude, longitude, density, cpi son de tipo object pero en realidad deberían ser numéricas. Crea una función que nos permita cambiar el tipo de dato de estas columnas al que le corresponde.

# %%
def cambio_dato(dato):
   try:
      dato = dato.replace(',', '')
      return float(dato)
   except:
      return np.nan

# %%
lista_columnas = ['density', 'land_area', 'armed_forces_size', 'co2-emissions', 'gdp', 'population', 'urban_population', 'latitude', 'longitude', 'cpi']

# %%
for columna in lista_columnas:
    world[columna] =  world[columna].apply(cambio_dato)

# %%
for columna in lista_columnas:
    print(world[columna].dtype)
# Out:
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64

# %% [markdown]
# Crea una función para añadir una nueva columna llamada 'Continent' al DataFrame para indicar a qué continente pertenece cada país.

# %%
world.head()
# Out:
#        country  density abbreviation  agricultural_land  land_area  \
# 0  Afghanistan     60.0           AF               58.1   652230.0
# 1      Albania    105.0           AL               43.1    28748.0
# 2      Algeria     18.0           DZ               17.4  2381741.0
# 3      Andorra    164.0           AD               40.0      468.0
# 4       Angola     26.0           AO               47.5  1246700.0
#
#    armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0           323000.0       32.49          93.0              Kabul
# 1             9000.0       11.78         355.0             Tirana
# 2           317000.0       24.28         213.0            Algiers
# 3                NaN        7.20         376.0   Andorra la Vella
# 4           117000.0       40.73         244.0             Luanda
#
#    co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# 0         8672.0  149.90         2.3           AFN            4.47
# 1         4536.0  119.05         1.4           ALL            1.62
# 2       150006.0  151.36         2.0           DZD            3.02
# 3          469.0     NaN         NaN           EUR            1.27
# 4        34693.0  261.73        17.1           AOA            5.52
#
#    forested_area  gasoline_price           gdp  \
# 0            2.1            0.70  1.910135e+10
# 1           28.1            1.36  1.527808e+10
# 2            0.8            0.28  1.699882e+11
# 3           34.0            1.51  3.154058e+09
# 4           46.3            0.97  9.463542e+10
#
#    gross_primary_education_enrollment  gross_tertiary_education_enrollment  \
# 0                               104.0                                  9.7
# 1                               107.0                                 55.0
# 2                               109.9                                 51.4
# 3                               106.4                                  NaN
# 4                               113.5                                  9.3
#
#    infant_mortality      largest_city  life_expectancy  \
# 0              47.9             Kabul             64.5
# 1               7.8            Tirana             78.5
# 2              20.1           Algiers             76.7
# 3               2.7  Andorra la Vella              NaN
# 4              51.6            Luanda             60.8
#
#    maternal_mortality_ratio  minimum_wage official_language  \
# 0                     638.0          0.43            Pashto
# 1                      15.0          1.12          Albanian
# 2                     112.0          0.95            Arabic
# 3                       NaN          6.63           Catalan
# 4                     241.0          0.71        Portuguese
#
#    out_of_pocket_health_expenditure  physicians_per_thousand  population  \
# 0                              78.4                     0.28  38041754.0
# 1                              56.9                     1.20   2854191.0
# 2                              28.1                     1.72  43053054.0
# 3                              36.4                     3.33     77142.0
# 4                              33.4                     0.21  31825295.0
#
#    population_labor_force_participation  tax_revenue  total_tax_rate  \
# 0                                  48.9          9.3            71.4
# 1                                  55.7         18.6            36.6
# 2                                  41.2         37.2            66.1
# 3                                   NaN          NaN             NaN
# 4                                  77.5          9.2            49.1
#
#    unemployment_rate  urban_population   latitude  longitude
# 0              11.12         9797273.0  33.939110  67.709953
# 1              12.33         1747593.0  41.153332  20.168331
# 2              11.70        31510100.0  28.033886   1.659626
# 3                NaN           67873.0  42.506285   1.521801
# 4               6.89        21061025.0 -11.202692  17.873887

# %%
continentes = {
    'Asia': ["Philippines", 'Afghanistan', 'Armenia', 'Azerbaijan', 'Bahrain', 'Bangladesh', 'Bhutan', 'Brunei', 'Cambodia', 'China', 'East Timor', 'India', 'Indonesia', 'Iran', 'Iraq', 'Israel', 'Japan', 'Jordan', 'Kazakhstan', 'Kuwait', 'Kyrgyzstan', 'Laos', 'Lebanon', 'Malaysia', 'Maldives', 'Mongolia', 'Myanmar', 'Nepal', 'North Korea', 'Oman', 'Pakistan', 'Palestinian National Authority', 'Qatar', 'Saudi Arabia', 'Singapore', 'South Korea', 'Sri Lanka', 'Syria', 'Tajikistan', 'Thailand', 'Turkmenistan', 'United Arab Emirates', 'Uzbekistan', 'Vietnam', 'Yemen'],
    'Africa': ["Tunisia", "Ivory Coast", 'Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cape Verde', 'Cameroon', 'Central African Republic', 'Chad', 'Comoros', 'Republic of the Congo', 'Cote d\'Ivoire', 'Democratic Republic of the Congo', 'Djibouti', 'Egypt', 'Equatorial Guinea', 'Eritrea', 'Eswatini', 'Ethiopia', 'Gabon', 'The Gambia', 'Ghana', 'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia', 'Libya', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda', 'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone', 'Somalia', 'South Africa', 'South Sudan', 'Sudan', 'Tanzania', 'Togo', 'Uganda', 'Zambia', 'Zimbabwe'],
    'Europe': ["Turkey", "Republic of Ireland", "Vatican City", 'Albania', 'Andorra', 'Austria', 'Belarus', 'Belgium', 'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Cyprus', 'Czech Republic', 'Denmark', 'Estonia', 'Finland', 'France', 'Georgia', 'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland', 'Italy', 'Latvia', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Malta', 'Moldova', 'Monaco', 'Montenegro', 'Netherlands', 'North Macedonia', 'Norway', 'Poland', 'Portugal', 'Romania', 'Russia', 'San Marino', 'Serbia', 'Slovakia', 'Slovenia', 'Spain', 'Sweden', 'Switzerland', 'Ukraine', 'United Kingdom'],
    "Central America":["Belize", "Saint Vincent and the Grenadines", "Saint Lucia", "Saint Kitts and Nevis", "Panama", "Nicaragua", "Mexico", "Jamaica", "Honduras", "Haiti", "Guatemala", "Grenada", "El Salvador", "Dominican Republic", "Dominica", "Cuba", "Antigua and Barbuda", "The Bahamas", "Barbados"," Belize", "Costa Rica",  ], 
    'North America': ['Canada', 'United States'],
    'South America': ["Trinidad and Tobago", 'Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 'Ecuador', 'Guyana', 'Paraguay', 'Peru', 'Suriname', 'Uruguay', 'Venezuela'],
    'Oceania': ["Papua New Guinea", "Federated States of Micronesia", 'Australia', 'Fiji', 'Kiribati', 'Marshall Islands', 'Nauru', 'New Zealand', 'Palau', 'Samoa', 'Solomon Islands', 'Tonga', 'Tuvalu', 'Vanuatu']
}

# %%
pais={'Africa': ["Tunisia", "Ivory Coast", 'Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cape Verde', 'Cameroon', 'Central African Republic', 'Chad', 'Comoros', 'Republic of the Congo', 'Cote d\'Ivoire', 'Democratic Republic of the Congo', 'Djibouti', 'Egypt', 'Equatorial Guinea', 'Eritrea', 'Eswatini', 'Ethiopia', 'Gabon', 'The Gambia', 'Ghana', 'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia', 'Libya', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda', 'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone', 'Somalia', 'South Africa', 'South Sudan', 'Sudan', 'Tanzania', 'Togo', 'Uganda', 'Zambia', 'Zimbabwe']}

# %%
def obtener_pais(diccionario,valor_buscado):
    for k,v in continentes.items():
        if valor_buscado in v:
            return k
    return None

# %%
resultado=obtener_pais(pais,'Zimbabwe')
print(resultado)
# Out:
# Africa

# %%
world["continent"] = world["country"].apply(lambda x: obtener_pais(pais, x))
world["continent"]
# Out:
# 0               Asia
# 1             Europe
# 2             Africa
# 3             Europe
# 4             Africa
#            ...
# 190    South America
# 191             Asia
# 192             Asia
# 193           Africa
# 194           Africa
# Name: continent, Length: 195, dtype: object

# %%
world["density"].value_counts(dropna=False, normalize=True)*100
# Out:
# density
# 25.0     3.589744
# 18.0     2.564103
# 83.0     2.564103
# 4.0      2.564103
# 16.0     1.538462
#            ...
# 81.0     0.512821
# 57.0     0.512821
# 239.0    0.512821
# 119.0    0.512821
# 38.0     0.512821
# Name: proportion, Length: 137, dtype: float64

# %% [markdown]
# ## 🔥 Resumen
#
# ✔ **`apply()`** recorre cada país en la columna `"country"`.
# ✔ **`lambda x: obtener_pais(pais, x)`** llama a `obtener_pais()` para encontrar el continente de cada país.
# ✔ **`obtener_pais(pais, x)`** busca el país en el diccionario `pais` y devuelve el continente.
# ✔ **El resultado** se almacena en la nueva columna `"continent"`.

# %%
world.sample(2)
# Out:
#                             country  density abbreviation  agricultural_land  \
# 35                            Chile     26.0           CL               21.2
# 111  Federated States of Micronesia    784.0           FM               31.4
#
#      land_area  armed_forces_size  birth_rate  calling_code  \
# 35    756096.0           122000.0       12.43          56.0
# 111      702.0                NaN       22.82         691.0
#
#     capital/major_city  co2-emissions     cpi  cpi_change currency-code  \
# 35            Santiago        85822.0  131.91         2.6           CLP
# 111            Palikir          143.0  112.10         0.5           USD
#
#      fertility_rate  forested_area  gasoline_price           gdp  \
# 35             1.65           24.3            1.03  2.823182e+11
# 111            3.05           91.9             NaN  4.019323e+08
#
#      gross_primary_education_enrollment  gross_tertiary_education_enrollment  \
# 35                                101.4                                 88.5
# 111                                97.2                                 14.1
#
#      infant_mortality largest_city  life_expectancy  maternal_mortality_ratio  \
# 35                6.2     Santiago             80.0                      13.0
# 111              25.6      Palikir             67.8                      88.0
#
#      minimum_wage official_language  out_of_pocket_health_expenditure  \
# 35            2.0           Spanish                              32.2
# 111           NaN           English                               2.5
#
#      physicians_per_thousand  population  \
# 35                      2.59  18952038.0
# 111                     0.18    113815.0
#
#      population_labor_force_participation  tax_revenue  total_tax_rate  \
# 35                                   62.6         18.2            34.0
# 111                                   NaN         25.2            60.5
#
#      unemployment_rate  urban_population   latitude   longitude      continent
# 35                7.09        16610135.0 -35.675147  -71.542969  South America
# 111                NaN           25963.0   7.425554  150.550812        Oceania

# %% [markdown]
# # 📌 Versiones de César en Clase
#
# Existen diferentes versiones del código de **César** que hemos visto en clase.

# %%
def obtener_contienente(dato):#versión de César en clase de repaso.
    continentes = {
    'Asia': ["Philippines", 'Afghanistan', 'Armenia', 'Azerbaijan', 'Bahrain', 'Bangladesh', 'Bhutan', 'Brunei', 'Cambodia', 'China', 'East Timor', 'India', 'Indonesia', 'Iran', 'Iraq', 'Israel', 'Japan', 'Jordan', 'Kazakhstan', 'Kuwait', 'Kyrgyzstan', 'Laos', 'Lebanon', 'Malaysia', 'Maldives', 'Mongolia', 'Myanmar', 'Nepal', 'North Korea', 'Oman', 'Pakistan', 'Palestinian National Authority', 'Qatar', 'Saudi Arabia', 'Singapore', 'South Korea', 'Sri Lanka', 'Syria', 'Tajikistan', 'Thailand', 'Turkmenistan', 'United Arab Emirates', 'Uzbekistan', 'Vietnam', 'Yemen'],
    'Africa': ["Tunisia", "Ivory Coast", 'Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cape Verde', 'Cameroon', 'Central African Republic', 'Chad', 'Comoros', 'Republic of the Congo', 'Cote d\'Ivoire', 'Democratic Republic of the Congo', 'Djibouti', 'Egypt', 'Equatorial Guinea', 'Eritrea', 'Eswatini', 'Ethiopia', 'Gabon', 'The Gambia', 'Ghana', 'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia', 'Libya', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda', 'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone', 'Somalia', 'South Africa', 'South Sudan', 'Sudan', 'Tanzania', 'Togo', 'Uganda', 'Zambia', 'Zimbabwe'],
    'Europe': ["Turkey", "Republic of Ireland", "Vatican City", 'Albania', 'Andorra', 'Austria', 'Belarus', 'Belgium', 'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Cyprus', 'Czech Republic', 'Denmark', 'Estonia', 'Finland', 'France', 'Georgia', 'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland', 'Italy', 'Latvia', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Malta', 'Moldova', 'Monaco', 'Montenegro', 'Netherlands', 'North Macedonia', 'Norway', 'Poland', 'Portugal', 'Romania', 'Russia', 'San Marino', 'Serbia', 'Slovakia', 'Slovenia', 'Spain', 'Sweden', 'Switzerland', 'Ukraine', 'United Kingdom'],
    "Central America":["Belize", "Saint Vincent and the Grenadines", "Saint Lucia", "Saint Kitts and Nevis", "Panama", "Nicaragua", "Mexico", "Jamaica", "Honduras", "Haiti", "Guatemala", "Grenada", "El Salvador", "Dominican Republic", "Dominica", "Cuba", "Antigua and Barbuda", "The Bahamas", "Barbados"," Belize", "Costa Rica",  ],
    'North America': ['Canada', 'United States'],
    'South America': ["Trinidad and Tobago", 'Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 'Ecuador', 'Guyana', 'Paraguay', 'Peru', 'Suriname', 'Uruguay', 'Venezuela'],
    'Oceania': ["Papua New Guinea", "Federated States of Micronesia", 'Australia', 'Fiji', 'Kiribati', 'Marshall Islands', 'Nauru', 'New Zealand', 'Palau', 'Samoa', 'Solomon Islands', 'Tonga', 'Tuvalu', 'Vanuatu']
}
    for k,v in continentes.items():
        if dato in v:
            return k

df["continent"] = df["country"].apply(obtener_contienente)

df[["country", "continent"]].head()

# %%
def obtener_continente_2(dato, diccionario):
    for k,v in diccionario.items():
        if dato in v:
            return k

# %%
df["continent_2"] = df.apply(lambda x: obtener_continente_2(x["country"], continentes), axis=1)
